# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Step 1: Initial GET request to collect cookies and CSRF token
url_main = "https://ifsc.results.info"
session = requests.Session()
response_main = session.get(url_main)
cookies = response_main.cookies

# Use BeautifulSoup to parse the response and extract CSRF token
soup = BeautifulSoup(response_main.text, 'html.parser')

# %%
csrf_token = soup.find('meta', {'name': 'csrf-token'})['content']
print(csrf_token)
# Out:
# 5UPntmtis1EUT6PGiiRvYiNuOrbJ/7XMYBQDQBlINivfLygAZ1wgF9YS02EqrXbodL686GbBDX6KwUY5IqnZoQ==

# %%
# Step 2: Use the collected cookies and CSRF token to make an authorized request to the API
url_api = "https://ifsc.results.info/api/v1/"
headers = {
    'X-CSRFToken': csrf_token,
    'Referer': url_main
}
response_api = session.get(url_api, headers=headers, cookies=cookies)

# Process the API response
data = response_api.json()
data['current'].keys()
# Out:
# dict_keys(['id', 'season', 'url', 'discipline_kinds', 'leagues'])

# %%
data['current']['leagues']
df = pd.DataFrame(data['current']['leagues'])

# %%
df
# Out:
#      id                                name  \
# 0   418  World Cups and World Championships
# 1   419                          IFSC Youth
# 2   420                   IFSC Paraclimbing
# 3   421                    IFSC Asia Adults
# 4   422                     IFSC Asia Youth
# 5   423                  IFSC Europe Adults
# 6   424                   IFSC Europe Youth
# 7   425                               Games
# 8   426                        Other events
# 9   427      Masters and Promotional Events
# 10  428             IFSC Pan America Adults
# 11  429                        IFSC Oceania
# 12  430                         IFSC Africa
#
#                                                  cups  \
# 0   [{'id': 90, 'name': 'IFSC Climbing World Cup 2...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'id': 92, 'name': 'IFSC-Europe Climbing Euro...
# 6   [{'id': 91, 'name': 'IFSC-Europe Climbing Euro...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
#
#                            url
# 0   /api/v1/season_leagues/418
# 1   /api/v1/season_leagues/419
# 2   /api/v1/season_leagues/420
# 3   /api/v1/season_leagues/421
# 4   /api/v1/season_leagues/422
# 5   /api/v1/season_leagues/423
# 6   /api/v1/season_leagues/424
# 7   /api/v1/season_leagues/425
# 8   /api/v1/season_leagues/426
# 9   /api/v1/season_leagues/427
# 10  /api/v1/season_leagues/428
# 11  /api/v1/season_leagues/429
# 12  /api/v1/season_leagues/430

# %%
data['current']['url']
# Out:
# '/api/v1/seasons/35'

# %%
preset_string = "World Cups and World Championships"  # Replace "example" with your preset string

filtered_lines = [line for line in data['current']['leagues'] if line['name'] == preset_string]
print(filtered_lines)
cup_id = filtered_lines[0]['cups'][0]['id']
filtered_lines[0]['cups'][0]['id']
# Out:
# [{'id': 418, 'name': 'World Cups and World Championships', 'cups': [{'id': 90, 'name': 'IFSC Climbing World Cup 2023'}], 'url': '/api/v1/season_leagues/418'}]
# 90

# %%
response_event = session.get(url_main + data['current']['url'], headers=headers, cookies=cookies)

# %%
eventData = response_event.json()

# %%
eventData['events']
for x in eventData['events']:
    if x['cup_id'] == cup_id:
        print(x['event'] + str(x['event_id']))
# Out:
# IFSC World Cup Hachioji 20231291
# IFSC World Cup Seoul 20231292
# IFSC World Cup Jakarta 20231293
# IFSC World Cup Salt Lake City 20231294
# IFSC World Cup Prague 20231295
# IFSC World Cup Brixen 20231296
# 22                                                   NaN             []
# 23                                                   NaN             []
# 24  IFSC-Europe Climbing European Youth Cup 2023    91.0             []
# 25                  IFSC Climbing World Cup 2023    90.0             []
# 26  IFSC-Europe Climbing European Youth Cup 2023    91.0             []
# 27                  IFSC Climbing World Cup 2023    90.0             []
# 28                                                   NaN             []
# 29                  IFSC Climbing World Cup 2023    90.0             []
# 30        IFSC-Europe Climbing European Cup 2023    92.0             []
# 31                                                   NaN             []
# 32                                                   NaN             []
# 33                                                   NaN             []
# 34                                                   NaN             []
# 35        IFSC-Europe Climbing European Cup 2023    92.0             []
# 36                                                   NaN             []
# 37                  IFSC Climbing World Cup 2023    90.0             []
# 38                                                   NaN             []
# 39  IFSC-Europe Climbing European Youth Cup 2023    91.0             []
# 40                                                   NaN             []
# 41                  IFSC Climbing World Cup 2023    90.0             []
# 42                                                   NaN             []
# 43  IFSC-Europe Climbing European Youth Cup 2023    91.0             []
# 44                                                   NaN             []
# 45                                                   NaN             []
# 46                                                   NaN             []
# 47                                                   NaN             []
# 48                                                   NaN             []
# 49                                                   NaN             []
# 50                                                   NaN             []
# 51                                                   NaN             []
# 52                                                   NaN             []
# 53                                                   NaN             []
# 54                                                   NaN             []
# 55                                                   NaN             []
# 56                                                   NaN             []
#
#                     url                   registration_url  \
# 0   /api/v1/events/1314  /api/v1/events/1314/registrations
# 1   /api/v1/events/1340  /api/v1/events/1340/registrations
# 2   /api/v1/events/1331  /api/v1/events/1331/registrations
# 3   /api/v1/events/1332  /api/v1/events/1332/registrations
# 4   /api/v1/events/1317  /api/v1/events/1317/registrations
# 5   /api/v1/events/1291  /api/v1/events/1291/registrations
# 6   /api/v1/events/1321  /api/v1/events/1321/registrations
# 7   /api/v1/events/1292  /api/v1/events/1292/registrations
# 8   /api/v1/events/1322  /api/v1/events/1322/registrations
# 9   /api/v1/events/1323  /api/v1/events/1323/registrations
# 10  /api/v1/events/1293  /api/v1/events/1293/registrations
# 11  /api/v1/events/1320  /api/v1/events/1320/registrations
# 12  /api/v1/events/1335  /api/v1/events/1335/registrations
# 13  /api/v1/events/1294  /api/v1/events/1294/registrations
# 14  /api/v1/events/1318  /api/v1/events/1318/registrations
# 15  /api/v1/events/1295  /api/v1/events/1295/registrations
# 16  /api/v1/events/1329  /api/v1/events/1329/registrations
# 17  /api/v1/events/1296  /api/v1/events/1296/registrations
# 18  /api/v1/events/1325  /api/v1/events/1325/registrations
# 19  /api/v1/events/1337  /api/v1/events/1337/registrations
# 20  /api/v1/events/1297  /api/v1/events/1297/registrations
# 21  /api/v1/events/1326  /api/v1/events/1326/registrations
# 22  /api/v1/events/1305  /api/v1/events/1305/registrations
# 23  /api/v1/events/1341  /api/v1/events/1341/registrations
# 24  /api/v1/events/1327  /api/v1/events/1327/registrations
# 25  /api/v1/events/1298  /api/v1/events/1298/registrations
# 26  /api/v1/events/1328  /api/v1/events/1328/registrations
# 27  /api/v1/events/1299  /api/v1/events/1299/registrations
# 28  /api/v1/events/1342  /api/v1/events/1342/registrations
# 29  /api/v1/events/1300  /api/v1/events/1300/registrations
# 30  /api/v1/events/1324  /api/v1/events/1324/registrations
# 31  /api/v1/events/1301  /api/v1/events/1301/registrations
# 32  /api/v1/events/1338  /api/v1/events/1338/registrations
# 33  /api/v1/events/1304  /api/v1/events/1304/registrations
# 34  /api/v1/events/1348  /api/v1/events/1348/registrations
# 35  /api/v1/events/1336  /api/v1/events/1336/registrations
# 36  /api/v1/events/1345  /api/v1/events/1345/registrations
# 37  /api/v1/events/1302  /api/v1/events/1302/registrations
# 38  /api/v1/events/1343  /api/v1/events/1343/registrations
# 39  /api/v1/events/1330  /api/v1/events/1330/registrations
# 40  /api/v1/events/1309  /api/v1/events/1309/registrations
# 41  /api/v1/events/1303  /api/v1/events/1303/registrations
# 42  /api/v1/events/1306  /api/v1/events/1306/registrations
# 43  /api/v1/events/1334  /api/v1/events/1334/registrations
# 44  /api/v1/events/1350  /api/v1/events/1350/registrations
# 45  /api/v1/events/1349  /api/v1/events/1349/registrations
# 46  /api/v1/events/1307  /api/v1/events/1307/registrations
# 47  /api/v1/events/1308  /api/v1/events/1308/registrations
# 48  /api/v1/events/1310  /api/v1/events/1310/registrations
# 49  /api/v1/events/1380  /api/v1/events/1380/registrations
# 50  /api/v1/events/1351  /api/v1/events/1351/registrations
# 51  /api/v1/events/1311  /api/v1/events/1311/registrations
# 52  /api/v1/events/1346  /api/v1/events/1346/registrations
# 53  /api/v1/events/1312  /api/v1/events/1312/registrations
# 54  /api/v1/events/1382  /api/v1/events/1382/registrations
# 55  /api/v1/events/1344  /api/v1/events/1344/registrations
# 56  /api/v1/events/1347  /api/v1/events/1347/registrations
#
#              infosheet_url additional_info_url                starts_at  \
# 0                     None                None  2023-03-10 23:00:00 UTC
# 1   /events/1340/infosheet                None  2023-03-24 23:00:00 UTC
# 2   /events/1331/infosheet                None  2023-03-31 22:00:00 UTC
# 3   /events/1332/infosheet                None  2023-03-31 22:00:00 UTC
# 4   /events/1317/infosheet                None  2023-04-06 22:00:00 UTC
# 5   /events/1291/infosheet                None  2023-04-20 15:00:00 UTC
# 6   /events/1321/infosheet                None  2023-04-21 23:00:00 UTC
# 7   /events/1292/infosheet                None  2023-04-27 15:00:00 UTC
# 8   /events/1322/infosheet                None  2023-04-27 21:00:00 UTC
# 9   /events/1323/infosheet                None  2023-05-04 22:00:00 UTC
# 10  /events/1293/infosheet                None  2023-05-05 17:00:00 UTC
# 11  /events/1320/infosheet                None  2023-05-11 22:00:00 UTC
# 12  /events/1335/infosheet                None  2023-05-16 06:00:00 UTC
# 13  /events/1294/infosheet                None  2023-05-19 06:00:00 UTC
# 14  /events/1318/infosheet                None  2023-05-26 22:00:00 UTC
# 15  /events/1295/infosheet                None  2023-06-01 22:00:00 UTC
# 16  /events/1329/infosheet                None  2023-06-07 22:00:00 UTC
# 17  /events/1296/infosheet                None  2023-06-08 22:00:00 UTC
# 18  /events/1325/infosheet                None  2023-06-11 22:00:00 UTC
# 19  /events/1337/infosheet                None  2023-06-11 22:00:00 UTC
# 20  /events/1297/infosheet                None  2023-06-13 22:00:00 UTC
# 54  2023-12-10 15:59:00 UTC       2023-12-08     2023-12-10
# 55  2023-12-16 20:59:00 UTC       2023-12-12     2023-12-16
# 56  2023-12-18 02:59:00 UTC       2023-12-15     2023-12-17
#
#                                        timezone  \
# 0                    {'value': 'Europe/Berlin'}
# 1                 {'value': 'Europe/Amsterdam'}
# 2                    {'value': 'Europe/Warsaw'}
# 3                    {'value': 'Europe/Warsaw'}
# 4                     {'value': 'Europe/Paris'}
# 5                       {'value': 'Asia/Tokyo'}
# 6                    {'value': 'Europe/Lisbon'}
# 7                       {'value': 'Asia/Seoul'}
# 8                   {'value': 'Europe/Vilnius'}
# 9                    {'value': 'Europe/Vienna'}
# 10                    {'value': 'Asia/Jakarta'}
# 11                   {'value': 'Europe/Madrid'}
# 12                  {'value': 'America/Denver'}
# 13                  {'value': 'America/Denver'}
# 14                 {'value': 'Europe/Brussels'}
# 15                   {'value': 'Europe/Prague'}
# 16                   {'value': 'Europe/Berlin'}
# 17                     {'value': 'Europe/Rome'}
# 18                   {'value': 'Europe/Vienna'}
# 19                   {'value': 'Europe/Vienna'}
# 20                   {'value': 'Europe/Vienna'}
# 21                   {'value': 'Europe/Zurich'}
# 22                   {'value': 'Europe/Warsaw'}
# 23                   {'value': 'Europe/Zurich'}
# 24                    {'value': 'Europe/Paris'}
# 25                   {'value': 'Europe/Zurich'}
# 26                   {'value': 'Europe/Vienna'}
# 27                    {'value': 'Europe/Paris'}
# 28                  {'value': 'Asia/Singapore'}
# 29                    {'value': 'Europe/Paris'}
# 30               {'value': 'Europe/Bratislava'}
# 31                   {'value': 'Europe/Zurich'}
# 32                   {'value': 'Europe/Zurich'}
# 33                      {'value': 'Asia/Seoul'}
# 34                     {'value': 'Europe/Rome'}
# 35                     {'value': 'Europe/Rome'}
# 36                {'value': 'Europe/Ljubljana'}
# 37                {'value': 'Europe/Ljubljana'}
# 38                  {'value': 'Asia/Hong_Kong'}
# 39                 {'value': 'Europe/Helsinki'}
# 40                     {'value': 'Europe/Rome'}
# 41                  {'value': 'Asia/Chongqing'}
# 42                  {'value': 'Asia/Chongqing'}
# 43                   {'value': 'Europe/Berlin'}
# 44                    {'value': 'Europe/Paris'}
# 45                   {'value': 'Asia/Shanghai'}
# 46                {'value': 'America/Santiago'}
# 47                    {'value': 'Europe/Paris'}
# 48                    {'value': 'Asia/Jakarta'}
# 49                   {'value': 'Asia/Shanghai'}
# 50                     {'value': 'Asia/Riyadh'}
# 51              {'value': 'Australia/Brisbane'}
# 52               {'value': 'America/Sao_Paulo'}
# 53             {'value': 'Africa/Johannesburg'}
# 54               {'value': 'Asia/Kuala_Lumpur'}
# 55                     {'value': 'Asia/Riyadh'}
# 56  {'value': 'America/Argentina/Buenos_Aires'}
#
#                                           disciplines
# 0   [{'id': 1574, 'kind': 'boulder', 'event_id': 1...
# 1                                                  []
# 2   [{'id': 1597, 'kind': 'speed', 'event_id': 133...
# 3   [{'id': 1598, 'kind': 'speed', 'event_id': 133...
# 4   [{'id': 1582, 'kind': 'boulder', 'event_id': 1...
# 5   [{'id': 1536, 'kind': 'boulder', 'event_id': 1...
# 6   [{'id': 1584, 'kind': 'boulder', 'event_id': 1...
# 7   [{'id': 1537, 'kind': 'boulder', 'event_id': 1...
# 8   [{'id': 1585, 'kind': 'boulder', 'event_id': 1...
# 9   [{'id': 1586, 'kind': 'boulder', 'event_id': 1...
# 10  [{'id': 1539, 'kind': 'speed', 'event_id': 129...
# 11  [{'id': 1583, 'kind': 'boulder', 'event_id': 1...
# 12  [{'id': 1604, 'kind': 'lead', 'event_id': 1335...
# 13  [{'id': 1540, 'kind': 'boulder', 'event_id': 1...
# 14  [{'id': 1581, 'kind': 'boulder', 'event_id': 1...
# 15  [{'id': 1542, 'kind': 'boulder', 'event_id': 1...
# 16  [{'id': 1594, 'kind': 'boulder', 'event_id': 1...
# 17  [{'id': 1543, 'kind': 'boulder', 'event_id': 1...
# 18  [{'id': 1589, 'kind': 'speed', 'event_id': 132...
# 19  [{'id': 1607, 'kind': 'lead', 'event_id': 1337...
# 20  [{'id': 1544, 'kind': 'boulder', 'event_id': 1...
# 21  [{'id': 1590, 'kind': 'lead', 'event_id': 1326...
# 22  [{'id': 1560, 'kind': 'boulder', 'event_id': 1...
# 23  [{'id': 1609, 'kind': 'lead', 'event_id': 1341...
# 24  [{'id': 1591, 'kind': 'lead', 'event_id': 1327...
# 25  [{'id': 1546, 'kind': 'lead', 'event_id': 1298...
# 26  [{'id': 1592, 'kind': 'lead', 'event_id': 1328...
# 27  [{'id': 1548, 'kind': 'lead', 'event_id': 1299...
# 28  [{'id': 1611, 'kind': 'speed', 'event_id': 134...
# 29  [{'id': 1550, 'kind': 'lead', 'event_id': 1300...
# 30  [{'id': 1587, 'kind': 'lead', 'event_id': 1324...
# 31  [{'id': 1551, 'kind': 'boulder', 'event_id': 1...
# 32  [{'id': 1608, 'kind': 'lead', 'event_id': 1338...
# 33  [{'id': 1557, 'kind': 'boulder', 'event_id': 1...
# 34                                                 []
# 35  [{'id': 1605, 'kind': 'lead', 'event_id': 1336...
# 36                                                 []
# 37  [{'id': 1554, 'kind': 'lead', 'event_id': 1302...
# 38  [{'id': 1612, 'kind': 'boulder', 'event_id': 1...
# 39  [{'id': 1596, 'kind': 'lead', 'event_id': 1330...
# 40  [{'id': 1566, 'kind': 'speed', 'event_id': 130...
# 41  [{'id': 1555, 'kind': 'lead', 'event_id': 1303...
# 42                                                 []
# 43  [{'id': 1603, 'kind': 'speed', 'event_id': 133...
# 44  [{'id': 1623, 'kind': 'boulder', 'event_id': 1...
# 45  [{'id': 1620, 'kind': 'lead', 'event_id': 1349...
# 46  [{'id': 1563, 'kind': 'speed', 'event_id': 130...
# 47  [{'id': 1565, 'kind': 'boulder&lead', 'event_i...
# 48  [{'id': 1567, 'kind': 'speed', 'event_id': 131...
# 49  [{'id': 1669, 'kind': 'speed', 'event_id': 138...
# 50  [{'id': 1625, 'kind': 'speed', 'event_id': 135...
# 51  [{'id': 1569, 'kind': 'speed', 'event_id': 131...
# 52  [{'id': 1617, 'kind': 'boulder', 'event_id': 1...
# 53  [{'id': 1571, 'kind': 'speed', 'event_id': 131...
# 54                                                 []
# 55  [{'id': 1614, 'kind': 'boulder', 'event_id': 1...
# 56  [{'id': 1618, 'kind': 'boulder', 'event_id': 1...

# %%
filtered_eventFrame = eventFrame[eventFrame['cup_id'] == cup_id]

# %%
filtered_eventFrame
# Out:
#                                  event  league_season_id           location  \
# 5         IFSC World Cup Hachioji 2023               418           Hachioji
# 7            IFSC World Cup Seoul 2023               418              Seoul
# 10         IFSC World Cup Jakarta 2023               418          Indonesia
# 13  IFSC World Cup Salt Lake City 2023               418     Salt Lake City
# 15          IFSC World Cup Prague 2023               418             Prague
# 17          IFSC World Cup Brixen 2023               418             Brixen
# 20       IFSC World Cup Innsbruck 2023               418          Innsbruck
# 25         IFSC World Cup Villars 2023               418  Villars-sur-Ollon
# 27        IFSC World Cup Chamonix 2023               418           Chamonix
# 29        IFSC World Cup Briançon 2023               418           Briançon
# 37           IFSC World Cup Koper 2023               418              Koper
# 41         IFSC World Cup Wujiang 2023               418            Wujiang
#
#     event_id                      cup_name  cup_id custom_cup_ids  \
# 5       1291  IFSC Climbing World Cup 2023    90.0             []
# 7       1292  IFSC Climbing World Cup 2023    90.0             []
# 10      1293  IFSC Climbing World Cup 2023    90.0             []
# 13      1294  IFSC Climbing World Cup 2023    90.0             []
# 15      1295  IFSC Climbing World Cup 2023    90.0             []
# 17      1296  IFSC Climbing World Cup 2023    90.0             []
# 20      1297  IFSC Climbing World Cup 2023    90.0             []
# 25      1298  IFSC Climbing World Cup 2023    90.0             []
# 27      1299  IFSC Climbing World Cup 2023    90.0             []
# 29      1300  IFSC Climbing World Cup 2023    90.0             []
# 37      1302  IFSC Climbing World Cup 2023    90.0             []
# 41      1303  IFSC Climbing World Cup 2023    90.0             []
#
#                     url                   registration_url  \
# 5   /api/v1/events/1291  /api/v1/events/1291/registrations
# 7   /api/v1/events/1292  /api/v1/events/1292/registrations
# 10  /api/v1/events/1293  /api/v1/events/1293/registrations
# 13  /api/v1/events/1294  /api/v1/events/1294/registrations
# 15  /api/v1/events/1295  /api/v1/events/1295/registrations
# 17  /api/v1/events/1296  /api/v1/events/1296/registrations
# 20  /api/v1/events/1297  /api/v1/events/1297/registrations
# 25  /api/v1/events/1298  /api/v1/events/1298/registrations
# 27  /api/v1/events/1299  /api/v1/events/1299/registrations
# 29  /api/v1/events/1300  /api/v1/events/1300/registrations
# 37  /api/v1/events/1302  /api/v1/events/1302/registrations
# 41  /api/v1/events/1303  /api/v1/events/1303/registrations
#
#              infosheet_url additional_info_url                starts_at  \
# 5   /events/1291/infosheet                None  2023-04-20 15:00:00 UTC
# 7   /events/1292/infosheet                None  2023-04-27 15:00:00 UTC
# 10  /events/1293/infosheet                None  2023-05-05 17:00:00 UTC
# 13  /events/1294/infosheet                None  2023-05-19 06:00:00 UTC
# 15  /events/1295/infosheet                None  2023-06-01 22:00:00 UTC
# 17  /events/1296/infosheet                None  2023-06-08 22:00:00 UTC
# 20  /events/1297/infosheet                None  2023-06-13 22:00:00 UTC
# 25  /events/1298/infosheet                None  2023-06-29 22:00:00 UTC
# 27  /events/1299/infosheet                None  2023-07-06 22:00:00 UTC
# 29  /events/1300/infosheet                None  2023-07-13 22:00:00 UTC
# 37  /events/1302/infosheet                None  2023-09-07 22:00:00 UTC
# 41  /events/1303/infosheet                None  2023-09-21 16:00:00 UTC
#
#                     ends_at local_start_date local_end_date  \
# 5   2023-04-23 14:59:00 UTC       2023-04-21     2023-04-23
# 7   2023-04-30 14:59:00 UTC       2023-04-28     2023-04-30
# 10  2023-05-07 16:59:00 UTC       2023-05-06     2023-05-07
# 13  2023-05-22 05:59:00 UTC       2023-05-19     2023-05-21
# 15  2023-06-04 21:59:00 UTC       2023-06-02     2023-06-04
# 17  2023-06-11 21:59:00 UTC       2023-06-09     2023-06-11
# 20  2023-06-18 21:59:00 UTC       2023-06-14     2023-06-18
# 25  2023-07-02 21:59:00 UTC       2023-06-30     2023-07-02
# 27  2023-07-09 21:59:00 UTC       2023-07-07     2023-07-09
# 29  2023-07-15 21:59:00 UTC       2023-07-14     2023-07-15
# 37  2023-09-09 21:59:00 UTC       2023-09-08     2023-09-09
# 41  2023-09-24 15:59:00 UTC       2023-09-22     2023-09-24
#
#                          timezone  \
# 5         {'value': 'Asia/Tokyo'}
# 7         {'value': 'Asia/Seoul'}
# 10      {'value': 'Asia/Jakarta'}
# 13    {'value': 'America/Denver'}
# 15     {'value': 'Europe/Prague'}
# 17       {'value': 'Europe/Rome'}
# 20     {'value': 'Europe/Vienna'}
# 25     {'value': 'Europe/Zurich'}
# 27      {'value': 'Europe/Paris'}
# 29      {'value': 'Europe/Paris'}
# 37  {'value': 'Europe/Ljubljana'}
# 41    {'value': 'Asia/Chongqing'}
#
#                                           disciplines
# 5   [{'id': 1536, 'kind': 'boulder', 'event_id': 1...
# 7   [{'id': 1537, 'kind': 'boulder', 'event_id': 1...
# 10  [{'id': 1539, 'kind': 'speed', 'event_id': 129...
# 13  [{'id': 1540, 'kind': 'boulder', 'event_id': 1...
# 15  [{'id': 1542, 'kind': 'boulder', 'event_id': 1...
# 17  [{'id': 1543, 'kind': 'boulder', 'event_id': 1...
# 20  [{'id': 1544, 'kind': 'boulder', 'event_id': 1...
# 25  [{'id': 1546, 'kind': 'lead', 'event_id': 1298...
# 27  [{'id': 1548, 'kind': 'lead', 'event_id': 1299...
# 29  [{'id': 1550, 'kind': 'lead', 'event_id': 1300...
# 37  [{'id': 1554, 'kind': 'lead', 'event_id': 1302...
# 41  [{'id': 1555, 'kind': 'lead', 'event_id': 1303...

# %%
singleEventR = session.get(url_main + '/api/v1/events/1291', headers=headers, cookies=cookies)
singleEvent = singleEventR.json()
singleEvent
# Out:
# {'id': 1291,
#  'name': 'IFSC World Cup Hachioji 2023',
#  'league_id': 1,
#  'league_season_id': 418,
#  'season_id': 35,
#  'starts_at': '2023-04-20 15:00:00 UTC',
#  'ends_at': '2023-04-23 14:59:00 UTC',
#  'local_start_date': '2023-04-21',
#  'local_end_date': '2023-04-23',
#  'timezone': {'value': 'Asia/Tokyo'},
#  'location': 'Hachioji',
#  'registration_url': '/api/v1/events/1291/registrations',
#  'public_information': {'organiser_name': 'Hachioji',
#   'organiser_url': None,
#   'venue_name': None},
#  'infosheet_url': '/events/1291/infosheet',
#  'additional_info_url': None,
#  'd_cats': [{'dcat_id': 3,
#    'event_id': 1291,
#    'dcat_name': 'BOULDER Men',
#    'discipline_kind': 'boulder',
#    'category_name': 'Men',
#    'status': 'finished',
#    'status_as_of': '2023-04-23 10:06:08 UTC',
#    'ranking_as_of': '2023-04-23 09:48:31 UTC',
#    'category_rounds': [{'category_round_id': 7669,
#      'kind': 'boulder',
#      'name': 'Qualification',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-21 12:15:52 UTC',
#      'result_url': '/api/v1/category_rounds/7669/results',
#      'starting_groups': [{'id': 145,
#        'name': 'Group A',
#        'ranking': '/api/v1/starting_groups/145/results',
#        'routes': [{'id': 8490,
#          'name': '1',
#          'startlist': '/api/v1/routes/8490/startlist'},
#         {'id': 8491,
#          'name': '2',
#          'startlist': '/api/v1/routes/8491/startlist'},
#         {'id': 8492,
#          'name': '3',
#          'startlist': '/api/v1/routes/8492/startlist'},
#         {'id': 8493,
#          'name': '4',
#          'startlist': '/api/v1/routes/8493/startlist'},
#         {'id': 8494,
#          'name': '5',
#          'startlist': '/api/v1/routes/8494/startlist'}]},
#       {'id': 146,
#        'name': 'Group B',
#        'ranking': '/api/v1/starting_groups/146/results',
#        'routes': [{'id': 8495,
#          'name': '1',
#          'startlist': '/api/v1/routes/8495/startlist'},
#         {'id': 8496,
#          'name': '2',
#          'startlist': '/api/v1/routes/8496/startlist'},
#         {'id': 8497,
#          'name': '3',
#          'startlist': '/api/v1/routes/8497/startlist'},
#         {'id': 8498,
#          'name': '4',
#          'startlist': '/api/v1/routes/8498/startlist'},
#         {'id': 8499,
#          'name': '5',
#          'startlist': '/api/v1/routes/8499/startlist'}]}],
#      'combined_stages': [],
#      'format': 'IFSC: 2 groups',
#      'routes': []},
#     {'category_round_id': 8120,
#      'kind': 'boulder',
#      'name': 'Semi-final',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-23 04:17:38 UTC',
#      'result_url': '/api/v1/category_rounds/8120/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: 1 group',
#      'routes': [{'id': 9891,
#        'name': '1',
#        'startlist': '/api/v1/routes/9891/startlist'},
#       {'id': 9892, 'name': '2', 'startlist': '/api/v1/routes/9892/startlist'},
#       {'id': 9893, 'name': '3', 'startlist': '/api/v1/routes/9893/startlist'},
#       {'id': 9894,
#        'name': '4',
#        'startlist': '/api/v1/routes/9894/startlist'}]},
#     {'category_round_id': 8122,
#      'kind': 'boulder',
#      'name': 'Final',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-23 10:03:03 UTC',
#      'result_url': '/api/v1/category_rounds/8122/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: Finals',
#      'routes': [{'id': 9899,
#        'name': '1',
#        'startlist': '/api/v1/routes/9899/startlist'},
#       {'id': 9900, 'name': '2', 'startlist': '/api/v1/routes/9900/startlist'},
#       {'id': 9901, 'name': '3', 'startlist': '/api/v1/routes/9901/startlist'},
#       {'id': 9902,
#        'name': '4',
#        'startlist': '/api/v1/routes/9902/startlist'}]}],
#    'full_results_url': '/api/v1/events/1291/result/3',
#    'top_3_results': [{'athlete_id': 11675,
#      'rank': 1,
#      'name': 'Schalck Mejdi',
#      'firstname': 'Mejdi',
#      'lastname': 'SCHALCK',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '4',
#      'country': 'FRA',
#      'flag_url': 'https://ifsc.results.info/images/flags/FRA.png',
#      'federation_id': 10,
#      'rounds': [{'category_round_id': 7669,
#        'round_name': 'Qualification',
#        'rank': 17,
#        'score': '4T4z 6 6',
#        'starting_group': 'Group A',
#        'ascents': [{'route_id': 8490,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 07:48:02 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8491,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 07:57:54 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8492,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:08:19 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8493,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 5,
#          'zone': False,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:22:24 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8494,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:29:47 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8120,
#        'round_name': 'Semi-final',
#        'rank': 4,
#        'score': '1T4z 2 9',
#        'ascents': [{'route_id': 9891,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:20:33 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9892,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 7,
#          'zone': True,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:31:17 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9893,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:41:51 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9894,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:50:29 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8122,
#        'round_name': 'Final',
#        'rank': 1,
#        'score': '2T3z 7 7',
#        'ascents': [{'route_id': 9899,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:24:39 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9900,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:50:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9901,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 9,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:19:31 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9902,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:48:30 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 373,
#      'rank': 2,
#      'name': 'Van Duysen Hannes',
#      'firstname': 'Hannes',
#      'lastname': 'VAN DUYSEN',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '77',
#      'country': 'BEL',
#      'flag_url': 'https://ifsc.results.info/images/flags/BEL.png',
#      'federation_id': 9,
#      'rounds': [{'category_round_id': 7669,
#        'round_name': 'Qualification',
#        'rank': 11,
#        'score': '3T5z 9 15',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8495,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 09:50:59 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8496,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 7,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:02:11 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8497,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 16,
#          'zone': True,
#          'zone_tries': 9,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:12:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8498,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:19:21 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8499,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:30:38 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8120,
#        'round_name': 'Semi-final',
#        'rank': 5,
#        'score': '1T4z 8 14',
#        'ascents': [{'route_id': 9891,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:51:53 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9892,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 8,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:02:01 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9893,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:13:16 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9894,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:23:45 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8122,
#        'round_name': 'Final',
#        'rank': 2,
#        'score': '1T3z 2 11',
#        'ascents': [{'route_id': 9899,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 9,
#          'zone': True,
#          'zone_tries': 9,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:20:12 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9900,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:45:51 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9901,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:14:53 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9902,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 5,
#          'zone': False,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:44:09 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 547,
#      'rank': 3,
#      'name': 'Jenft Paul',
#      'firstname': 'Paul',
#      'lastname': 'JENFT',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '7',
#      'country': 'FRA',
#      'flag_url': 'https://ifsc.results.info/images/flags/FRA.png',
#      'federation_id': 10,
#      'rounds': [{'category_round_id': 7669,
#        'round_name': 'Qualification',
#        'rank': 7,
#        'score': '4T5z 10 9',
#        'starting_group': 'Group A',
#        'ascents': [{'route_id': 8490,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:02:56 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8491,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:14:58 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8492,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:23:44 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8493,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:37:54 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8494,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:46:58 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8120,
#        'round_name': 'Semi-final',
#        'rank': 1,
#        'score': '2T4z 11 13',
#        'ascents': [{'route_id': 9891,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:07:50 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9892,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 9,
#          'zone': True,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:18:40 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9893,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:28:46 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9894,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 03:38:57 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8122,
#        'round_name': 'Final',
#        'rank': 3,
#        'score': '1T3z 3 3',
#        'ascents': [{'route_id': 9899,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:37:53 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9900,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:02:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9901,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:33:52 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9902,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 5,
#          'zone': False,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 10:02:00 +00:00',
#          'status': 'confirmed'}]}]}]},
#   {'dcat_id': 7,
#    'event_id': 1291,
#    'dcat_name': 'BOULDER Women',
#    'discipline_kind': 'boulder',
#    'category_name': 'Women',
#    'status': 'finished',
#    'status_as_of': '2023-04-22 10:00:32 UTC',
#    'ranking_as_of': '2023-04-22 09:44:50 UTC',
#    'category_rounds': [{'category_round_id': 7670,
#      'kind': 'boulder',
#      'name': 'Qualification',
#      'category': 'Women',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-21 04:00:59 UTC',
#      'result_url': '/api/v1/category_rounds/7670/results',
#      'starting_groups': [{'id': 147,
#        'name': 'Group A',
#        'ranking': '/api/v1/starting_groups/147/results',
#        'routes': [{'id': 8500,
#          'name': '1',
#          'startlist': '/api/v1/routes/8500/startlist'},
#         {'id': 8501,
#          'name': '2',
#          'startlist': '/api/v1/routes/8501/startlist'},
#         {'id': 8502,
#          'name': '3',
#          'startlist': '/api/v1/routes/8502/startlist'},
#         {'id': 8503,
#          'name': '4',
#          'startlist': '/api/v1/routes/8503/startlist'},
#         {'id': 8504,
#          'name': '5',
#          'startlist': '/api/v1/routes/8504/startlist'}]},
#       {'id': 148,
#        'name': 'Group B',
#        'ranking': '/api/v1/starting_groups/148/results',
#        'routes': [{'id': 8505,
#          'name': '1',
#          'startlist': '/api/v1/routes/8505/startlist'},
#         {'id': 8506,
#          'name': '2',
#          'startlist': '/api/v1/routes/8506/startlist'},
#         {'id': 8507,
#          'name': '3',
#          'startlist': '/api/v1/routes/8507/startlist'},
#         {'id': 8508,
#          'name': '4',
#          'startlist': '/api/v1/routes/8508/startlist'},
#         {'id': 8509,
#          'name': '5',
#          'startlist': '/api/v1/routes/8509/startlist'}]}],
#      'combined_stages': [],
#      'format': 'IFSC: 2 groups',
#      'routes': []},
#     {'category_round_id': 8121,
#      'kind': 'boulder',
#      'name': 'Semi-final',
#      'category': 'Women',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-22 04:22:33 UTC',
#      'result_url': '/api/v1/category_rounds/8121/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: 1 group',
#      'routes': [{'id': 9895,
#        'name': '1',
#        'startlist': '/api/v1/routes/9895/startlist'},
#       {'id': 9896, 'name': '2', 'startlist': '/api/v1/routes/9896/startlist'},
#       {'id': 9897, 'name': '3', 'startlist': '/api/v1/routes/9897/startlist'},
#       {'id': 9898,
#        'name': '4',
#        'startlist': '/api/v1/routes/9898/startlist'}]},
#     {'category_round_id': 8123,
#      'kind': 'boulder',
#      'name': 'Final',
#      'category': 'Women',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-22 09:55:10 UTC',
#      'result_url': '/api/v1/category_rounds/8123/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: Finals',
#      'routes': [{'id': 9903,
#        'name': '1',
#        'startlist': '/api/v1/routes/9903/startlist'},
#       {'id': 9904, 'name': '2', 'startlist': '/api/v1/routes/9904/startlist'},
#       {'id': 9905, 'name': '3', 'startlist': '/api/v1/routes/9905/startlist'},
#       {'id': 9906,
#        'name': '4',
#        'startlist': '/api/v1/routes/9906/startlist'}]}],
#    'full_results_url': '/api/v1/events/1291/result/7',
#    'top_3_results': [{'athlete_id': 1811,
#      'rank': 1,
#      'name': 'Raboutou Brooke',
#      'firstname': 'Brooke',
#      'lastname': 'RABOUTOU',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '142',
#      'country': 'USA',
#      'flag_url': 'https://ifsc.results.info/images/flags/USA.png',
#      'federation_id': 20,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 3,
#        'score': '5T5z 12 12',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8505,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:06:41 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8506,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:17:37 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8507,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 8,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:36:57 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8508,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:38:45 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8509,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:48:31 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 3,
#        'score': '2T4z 5 6',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:39:20 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:49:29 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:56:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:10:43 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 1,
#        'score': '3T4z 6 6',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:25:44 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:50:48 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:18:57 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:44:50 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 3113,
#      'rank': 2,
#      'name': 'Meul Hannah',
#      'firstname': 'Hannah',
#      'lastname': 'MEUL',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '143',
#      'country': 'GER',
#      'flag_url': 'https://ifsc.results.info/images/flags/GER.png',
#      'federation_id': 6,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 7,
#        'score': '4T5z 6 5',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8505,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:12:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8506,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:23:16 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8507,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:36:55 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8508,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:44:08 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8509,
#          'route_name': '5',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:57:47 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 1,
#        'score': '2T4z 4 5',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:18:25 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:28:42 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:36:00 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:49:43 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 2,
#        'score': '1T3z 1 8',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:34:01 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:59:31 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:27:52 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': False,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:54:08 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 12297,
#      'rank': 3,
#      'name': 'Matsufuji Anon',
#      'firstname': 'Anon',
#      'lastname': 'MATSUFUJI',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '111',
#      'country': 'JPN',
#      'flag_url': 'https://ifsc.results.info/images/flags/JPN.png',
#      'federation_id': 25,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 1,
#        'score': '5T5z 5 5',
#        'starting_group': 'Group A',
#        'ascents': [{'route_id': 8500,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:54:40 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8501,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:05:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8502,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:15:12 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8503,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:25:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8504,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:36:34 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 4,
#        'score': '2T3z 5 6',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:44:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:52:15 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:05:12 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:15:52 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 3,
#        'score': '0T3z 0 7',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:24:05 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:46:13 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:16:21 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:42:23 +00:00',
#          'status': 'confirmed'}]}]}]}],
#  'dcats': [{'dcat_id': 3,
#    'event_id': 1291,
#    'dcat_name': 'BOULDER Men',
#    'discipline_kind': 'boulder',
#    'category_name': 'Men',
#    'status': 'finished',
#    'status_as_of': '2023-04-23 10:06:08 UTC',
#    'ranking_as_of': '2023-04-23 09:48:31 UTC',
#    'category_rounds': [{'category_round_id': 7669,
#      'kind': 'boulder',
#      'name': 'Qualification',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-21 12:15:52 UTC',
#      'result_url': '/api/v1/category_rounds/7669/results',
#      'starting_groups': [{'id': 145,
#        'name': 'Group A',
#        'ranking': '/api/v1/starting_groups/145/results',
#        'routes': [{'id': 8490,
#          'name': '1',
#          'startlist': '/api/v1/routes/8490/startlist'},
#         {'id': 8491,
#          'name': '2',
#          'startlist': '/api/v1/routes/8491/startlist'},
#         {'id': 8492,
#          'name': '3',
#          'startlist': '/api/v1/routes/8492/startlist'},
#         {'id': 8493,
#          'name': '4',
#          'startlist': '/api/v1/routes/8493/startlist'},
#         {'id': 8494,
#          'name': '5',
#          'startlist': '/api/v1/routes/8494/startlist'}]},
#       {'id': 146,
#        'name': 'Group B',
#        'ranking': '/api/v1/starting_groups/146/results',
#        'routes': [{'id': 8495,
#          'name': '1',
#          'startlist': '/api/v1/routes/8495/startlist'},
#         {'id': 8496,
#          'name': '2',
#          'startlist': '/api/v1/routes/8496/startlist'},
#         {'id': 8497,
#          'name': '3',
#          'startlist': '/api/v1/routes/8497/startlist'},
#         {'id': 8498,
#          'name': '4',
#          'startlist': '/api/v1/routes/8498/startlist'},
#         {'id': 8499,
#          'name': '5',
#          'startlist': '/api/v1/routes/8499/startlist'}]}],
#      'combined_stages': [],
#      'format': 'IFSC: 2 groups',
#      'routes': []},
#     {'category_round_id': 8120,
#      'kind': 'boulder',
#      'name': 'Semi-final',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-23 04:17:38 UTC',
#      'result_url': '/api/v1/category_rounds/8120/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: 1 group',
#      'routes': [{'id': 9891,
#        'name': '1',
#        'startlist': '/api/v1/routes/9891/startlist'},
#       {'id': 9892, 'name': '2', 'startlist': '/api/v1/routes/9892/startlist'},
#       {'id': 9893, 'name': '3', 'startlist': '/api/v1/routes/9893/startlist'},
#       {'id': 9894,
#        'name': '4',
#        'startlist': '/api/v1/routes/9894/startlist'}]},
#     {'category_round_id': 8122,
#      'kind': 'boulder',
#      'name': 'Final',
#      'category': 'Men',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-23 10:03:03 UTC',
#      'result_url': '/api/v1/category_rounds/8122/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: Finals',
#      'routes': [{'id': 9899,
#        'name': '1',
#        'startlist': '/api/v1/routes/9899/startlist'},
#       {'id': 9900, 'name': '2', 'startlist': '/api/v1/routes/9900/startlist'},
#       {'id': 9901, 'name': '3', 'startlist': '/api/v1/routes/9901/startlist'},
#       {'id': 9902,
#        'name': '4',
#        'startlist': '/api/v1/routes/9902/startlist'}]}],
#    'full_results_url': '/api/v1/events/1291/result/3',
#    'top_3_results': [{'athlete_id': 11675,
#      'rank': 1,
#      'name': 'Schalck Mejdi',
#      'firstname': 'Mejdi',
#      'lastname': 'SCHALCK',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '4',
#      'country': 'FRA',
#      'flag_url': 'https://ifsc.results.info/images/flags/FRA.png',
#      'federation_id': 10,
#      'rounds': [{'category_round_id': 7669,
#        'round_name': 'Qualification',
#        'rank': 17,
#        'score': '4T4z 6 6',
#        'starting_group': 'Group A',
#        'ascents': [{'route_id': 8490,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 07:48:02 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8491,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 07:57:54 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8492,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:08:19 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8493,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 5,
#          'zone': False,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:22:24 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8494,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 08:29:47 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8120,
#        'round_name': 'Semi-final',
#        'rank': 4,
#        'score': '1T4z 2 9',
#        'ascents': [{'route_id': 9891,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:20:33 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9892,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 7,
#          'zone': True,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:31:17 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9893,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:41:51 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9894,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:50:29 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8122,
#        'round_name': 'Final',
#        'rank': 1,
#        'score': '2T3z 7 7',
#        'ascents': [{'route_id': 9899,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:24:39 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9900,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 08:50:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9901,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 9,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:19:31 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9902,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 09:48:30 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 373,
#      'rank': 2,
#      'name': 'Van Duysen Hannes',
#      'firstname': 'Hannes',
#      'lastname': 'VAN DUYSEN',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '77',
#      'country': 'BEL',
#      'flag_url': 'https://ifsc.results.info/images/flags/BEL.png',
#      'federation_id': 9,
#      'rounds': [{'category_round_id': 7669,
#        'round_name': 'Qualification',
#        'rank': 11,
#        'score': '3T5z 9 15',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8495,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 09:50:59 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8496,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 7,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:02:11 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8497,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 16,
#          'zone': True,
#          'zone_tries': 9,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:12:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8498,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:19:21 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8499,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 10:30:38 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8120,
#        'round_name': 'Semi-final',
#        'rank': 5,
#        'score': '1T4z 8 14',
#        'ascents': [{'route_id': 9891,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-23 02:51:53 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9892,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 8,
#          'low_zone': False,
#          'points': None,
# ...
#       {'id': 9896, 'name': '2', 'startlist': '/api/v1/routes/9896/startlist'},
#       {'id': 9897, 'name': '3', 'startlist': '/api/v1/routes/9897/startlist'},
#       {'id': 9898,
#        'name': '4',
#        'startlist': '/api/v1/routes/9898/startlist'}]},
#     {'category_round_id': 8123,
#      'kind': 'boulder',
#      'name': 'Final',
#      'category': 'Women',
#      'schedule': None,
#      'status': 'finished',
#      'status_as_of': '2023-04-22 09:55:10 UTC',
#      'result_url': '/api/v1/category_rounds/8123/results',
#      'starting_groups': [],
#      'combined_stages': [],
#      'format': 'IFSC: Finals',
#      'routes': [{'id': 9903,
#        'name': '1',
#        'startlist': '/api/v1/routes/9903/startlist'},
#       {'id': 9904, 'name': '2', 'startlist': '/api/v1/routes/9904/startlist'},
#       {'id': 9905, 'name': '3', 'startlist': '/api/v1/routes/9905/startlist'},
#       {'id': 9906,
#        'name': '4',
#        'startlist': '/api/v1/routes/9906/startlist'}]}],
#    'full_results_url': '/api/v1/events/1291/result/7',
#    'top_3_results': [{'athlete_id': 1811,
#      'rank': 1,
#      'name': 'Raboutou Brooke',
#      'firstname': 'Brooke',
#      'lastname': 'RABOUTOU',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '142',
#      'country': 'USA',
#      'flag_url': 'https://ifsc.results.info/images/flags/USA.png',
#      'federation_id': 20,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 3,
#        'score': '5T5z 12 12',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8505,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:06:41 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8506,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:17:37 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8507,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 8,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:36:57 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8508,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:38:45 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8509,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:48:31 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 3,
#        'score': '2T4z 5 6',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:39:20 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:49:29 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:56:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:10:43 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 1,
#        'score': '3T4z 6 6',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:25:44 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:50:48 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:18:57 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:44:50 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 3113,
#      'rank': 2,
#      'name': 'Meul Hannah',
#      'firstname': 'Hannah',
#      'lastname': 'MEUL',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '143',
#      'country': 'GER',
#      'flag_url': 'https://ifsc.results.info/images/flags/GER.png',
#      'federation_id': 6,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 7,
#        'score': '4T5z 6 5',
#        'starting_group': 'Group B',
#        'ascents': [{'route_id': 8505,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:12:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8506,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:23:16 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8507,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:36:55 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8508,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:44:08 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8509,
#          'route_name': '5',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:57:47 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 1,
#        'score': '2T4z 4 5',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:18:25 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:28:42 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:36:00 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:49:43 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 2,
#        'score': '1T3z 1 8',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:34:01 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:59:31 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 8,
#          'zone': True,
#          'zone_tries': 5,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:27:52 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': False,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:54:08 +00:00',
#          'status': 'confirmed'}]}]},
#     {'athlete_id': 12297,
#      'rank': 3,
#      'name': 'Matsufuji Anon',
#      'firstname': 'Anon',
#      'lastname': 'MATSUFUJI',
#      'paraclimbing_sport_class': None,
#      'sport_class_status': None,
#      'bib': '111',
#      'country': 'JPN',
#      'flag_url': 'https://ifsc.results.info/images/flags/JPN.png',
#      'federation_id': 25,
#      'rounds': [{'category_round_id': 7670,
#        'round_name': 'Qualification',
#        'rank': 1,
#        'score': '5T5z 5 5',
#        'starting_group': 'Group A',
#        'ascents': [{'route_id': 8500,
#          'route_name': '1',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 00:54:40 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8501,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:05:06 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8502,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:15:12 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8503,
#          'route_name': '4',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:25:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 8504,
#          'route_name': '5',
#          'top': True,
#          'top_tries': 1,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-21 01:36:34 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8121,
#        'round_name': 'Semi-final',
#        'rank': 4,
#        'score': '2T3z 5 6',
#        'ascents': [{'route_id': 9895,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:44:38 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9896,
#          'route_name': '2',
#          'top': True,
#          'top_tries': 2,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 03:52:15 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9897,
#          'route_name': '3',
#          'top': True,
#          'top_tries': 3,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:05:12 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9898,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 3,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 04:15:52 +00:00',
#          'status': 'confirmed'}]},
#       {'category_round_id': 8123,
#        'round_name': 'Final',
#        'rank': 3,
#        'score': '0T3z 0 7',
#        'ascents': [{'route_id': 9903,
#          'route_name': '1',
#          'top': False,
#          'top_tries': 5,
#          'zone': True,
#          'zone_tries': 1,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:24:05 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9904,
#          'route_name': '2',
#          'top': False,
#          'top_tries': 6,
#          'zone': True,
#          'zone_tries': 4,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 08:46:13 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9905,
#          'route_name': '3',
#          'top': False,
#          'top_tries': 4,
#          'zone': True,
#          'zone_tries': 2,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:16:21 +00:00',
#          'status': 'confirmed'},
#         {'route_id': 9906,
#          'route_name': '4',
#          'top': False,
#          'top_tries': 6,
#          'zone': False,
#          'zone_tries': 6,
#          'low_zone': False,
#          'points': None,
#          'low_zone_tries': None,
#          'modified': '2023-04-22 09:42:23 +00:00',
#          'status': 'confirmed'}]}]}]}],
#  'computed_combined_categories': [],
#  'team_ranking_disciplines': ['boulder'],
#  'team_ranking_url': '/api/v1/events/1291/team_results/'}

# %%
singleEvent['d_cats'][0]['category_rounds'][0]
# Out:
# {'category_round_id': 7669,
#  'kind': 'boulder',
#  'name': 'Qualification',
#  'category': 'Men',
#  'schedule': None,
#  'status': 'finished',
#  'status_as_of': '2023-04-21 12:15:52 UTC',
#  'result_url': '/api/v1/category_rounds/7669/results',
#  'starting_groups': [{'id': 145,
#    'name': 'Group A',
#    'ranking': '/api/v1/starting_groups/145/results',
#    'routes': [{'id': 8490,
#      'name': '1',
#      'startlist': '/api/v1/routes/8490/startlist'},
#     {'id': 8491, 'name': '2', 'startlist': '/api/v1/routes/8491/startlist'},
#     {'id': 8492, 'name': '3', 'startlist': '/api/v1/routes/8492/startlist'},
#     {'id': 8493, 'name': '4', 'startlist': '/api/v1/routes/8493/startlist'},
#     {'id': 8494, 'name': '5', 'startlist': '/api/v1/routes/8494/startlist'}]},
#   {'id': 146,
#    'name': 'Group B',
#    'ranking': '/api/v1/starting_groups/146/results',
#    'routes': [{'id': 8495,
#      'name': '1',
#      'startlist': '/api/v1/routes/8495/startlist'},
#     {'id': 8496, 'name': '2', 'startlist': '/api/v1/routes/8496/startlist'},
#     {'id': 8497, 'name': '3', 'startlist': '/api/v1/routes/8497/startlist'},
#     {'id': 8498, 'name': '4', 'startlist': '/api/v1/routes/8498/startlist'},
#     {'id': 8499, 'name': '5', 'startlist': '/api/v1/routes/8499/startlist'}]}],
#  'combined_stages': [],
#  'format': 'IFSC: 2 groups',
#  'routes': []}

# %%
# parse the api/event/{eventId} response and get the url of each round result api 
for e in singleEvent['d_cats'][0]['category_rounds']:
    print(e['name'], e['kind'], e['category'], e['result_url'])
# Out:
# Qualification boulder Men /api/v1/category_rounds/7669/results
# Semi-final boulder Men /api/v1/category_rounds/8120/results
# Final boulder Men /api/v1/category_rounds/8122/results
